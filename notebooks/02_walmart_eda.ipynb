# %% [markdown]
# # 02 - Walmart Sales: EDA
#
# **Dataset:** `data/raw/Walmart.csv`
# **Order:** 2 of 6
#
# Goals:
# 1. Load and inspect raw data
# 2. Check shape, dtypes, missing values, duplicates
# 3. Univariate & bivariate exploration
# 4. Note cleaning steps to feed into `src/data_preprocessing/walmart_cleaning.py`
# 5. Save key findings to `reports/insights/`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')

RAW_PATH = '../data/raw/Walmart.csv'

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv(RAW_PATH)
print(df.shape)
df.head()

# %% [markdown]
# ## 2. Structure & Data Types

# %%
df.info()

# %%
df.describe(include='all').T

# %% [markdown]
# ## 3. Missing Values & Duplicates

# %%
missing = df.isna().sum().sort_values(ascending=False)
missing[missing > 0]

# %%
print('Duplicate rows:', df.duplicated().sum())

# %% [markdown]
# ## 4. Univariate Analysis

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
print(numeric_cols)

df[numeric_cols].hist(figsize=(14, 10), bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Bivariate / Categorical Exploration

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()
print(categorical_cols)

for col in categorical_cols[:5]:
    print(df[col].value_counts().head(10))
    print('---')

# %% [markdown]
# ## 6. Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap - Walmart Sales')
plt.tight_layout()
plt.savefig('../reports/figures/walmart_correlation_heatmap.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Cleaning Notes (feed into `walmart_cleaning.py`)
#
# - [ ] Columns needing dtype fixes:
# - [ ] Columns with missing values & how to handle:
# - [ ] Outliers spotted:
# - [ ] Date columns to parse:
# - [ ] Key business insight for `reports/insights/`:
